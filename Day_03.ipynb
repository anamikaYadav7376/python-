# %% [markdown]
# <a href="https://colab.research.google.com/github/anamikaYadav7376/python-/blob/main/Day_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function in Python

# %%
def fun_name(parameters):
  # body of the function

# %%
 def add (x,y):
   return x + y ;
 add(2,3)
# Out:
# 5

# %%
# lambda function

# do not use return keyWord but it return something

x = lambda a : 2*a
print(x(3))
# Out:
# 6

# %% [markdown]
# # String

# %%
st = ""
print(len(st))

st = "anAmIkA yAdAv"

# to Captalized (it will not change orignal string)
w = st.upper()
print(w)

x = st.lower()
print(x)

# all word first letter will be "capital"
y = st.title()
print(y)

# first word first letter will be "capital"
z = st.capitalize()
print(z)
# Out:
# 0
# ANAMIKA YADAV
# anamika yadav
# Anamika Yadav
# Anamika yadav

# %%
st = "   Solo Leveling  "

# strip = to remove leading and trailing spaces

x = st.strip()
print(x)
# Out:
# Solo Leveling

# %%
a =' today'
b = '    weather'
c= 'is GooD'

first = a.strip().capitalize()
sec = b.strip().lower()
third = c.strip().lower()

fourth = c.replace('is GooD','is bad')

print( first +' ' + sec + ' ' + third)
print( first +' ' + sec + ' ' + fourth)


# .find() = finds index (-1 if not found), index() finds index
st = "Today weather is good"
f = st.find("z")
print (f)

g = st.index("o")  # gives error if string is not found
print (g)

h = st.startswith("T")  # return true false according to first element
print(h)

i = st.startswith("h")  # return true false according to last element
print(i)
# Out:
# Today weather is good
# Today weather is bad
# -1
# 1
# True
# False

# %%
# slicing

s = "Hello World"

print ( s[0 : 5] )
print( s[1::9] )
# Out:
# Hello

# %% [markdown]
# # Set
#
# sort and remove duplicate

# %%
# explore sets function gfg / w3school

st = { 2,3,5,2}
print(st)
# Out:
# {2, 3, 5}

# %% [markdown]
# # Dictionary
#
# store data in (key : value) pair

# %%
# Dictionary

dct = {
    "name" : "Ank" ,
    "age" : 19,
    "occupation" : "Student",
    "Degree" : "B.Tech"
}

print (dct['name'])  # Ank
print (dct['name'][0])  # A

# add new element
dct ['id'] = 12
print(dct)

# delete an element
del dct["name"]
print (dct)
# Out:
# Ank
# A
# {'name': 'Ank', 'age': 19, 'occupation': 'Student', 'Degree': 'B.Tech', 'id': 12}
# {'age': 19, 'occupation': 'Student', 'Degree': 'B.Tech', 'id': 12}
